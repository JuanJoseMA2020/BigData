# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanJoseMA2020/BigData/blob/main/Clase14_02_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #Manejo de listas(Vectores)
import pandas as pd #Manejo del csv
import matplotlib.pyplot as plt #Visualizaciones
import seaborn as sns #Visualizaciones

# %% [markdown]
# Importamos la base de datos

# %%
df=pd.read_csv("/content/drive/MyDrive/Ingeniería de Sistemas/2023-1/BigData/StudentsPerformance.csv")

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df = df.rename(columns={'parental level of education':'parental_education'}) #Nombre de la columna alterado

# %%
df = df.rename(columns={'test preparation course':'preparation'}) #Nombre de la columna alterado

# %%
df=pd.read_csv("/content/drive/MyDrive/Ingeniería de Sistemas/2023-1/BigData/StudentsPerformance.csv")
df.head(5)  #Sirve para dibujar las primeros cinco filas de DF
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df['gender']=df['gender'].astype('category')
df['race/ethnicity']=df['race/ethnicity'].astype('category')
df['parental level of education']=df['parental level of education'].astype('category')
df['lunch']=df['lunch'].astype('category')
df['test preparation course']=df['test preparation course'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   category
#  1   race/ethnicity               1000 non-null   category
#  2   parental level of education  1000 non-null   category
#  3   lunch                        1000 non-null   category
#  4   test preparation course      1000 non-null   category
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: category(5), int64(3)
# memory usage: 29.2 KB

# %%
sns.countplot(data=df,x='gender') #Sirve para dibujar un diagrama de barras

# %%
df['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
sns.histplot(data=df,x='math score',bins=10) #Cantidad de barritas en el histograma se denomia como "bins"

# %%
sns.histplot(data=df,x='reading score',bins=15)

# %%
sns.histplot(data=df,x='writing score',bins=15)

# %%
fig=plt.figure(figsize=(20,7))
ax1=fig.add_subplot(131)
ax2=fig.add_subplot(132)
ax3=fig.add_subplot(133)

sns.boxplot(data=df,y='reading score', ax=ax1) #Diagrama de cajas
sns.boxplot(data=df,y='math score', ax=ax2) #Diagrama de cajas
sns.boxplot(data=df,y='writing score', ax=ax3) #Diagrama de cajas

# %%
sns.boxplot(data=df,y='math score') #Diagrama de cajas

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
sns.scatterplot(data=df,y='math score',x='writing score',hue='lunch') #Diagrama de dispersión (Solo relaciona dos variables númericas) (hue es usado como una leyendo para traer valores de otra columna)

# %%
sns.boxplot(data=df,x='reading score',y='lunch')

# %%
dfmath = df[df['math score']>60]
sns.countplot(data=dfmath,x='gender')

# %%
dfreading =df[df['reading score']>60]
sns.countplot(data=dfreading, x='gender')

# %%
dfwriting =df[df['writing score']>60]
sns.countplot(data=dfwriting, x='gender')

# %% [markdown]
# COMPARAR EL PUNTAJE DE READING DEL GRUPO A CON EL GRUPO B

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
dfFiltro = df[df['race/ethnicity'].isin(['group A', 'group B'])]
dfFiltro.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 2                    none          90             95             93
# 3                    none          47             57             44
# 5                    none          71             83             78
# 6               completed          88             95             92

# %%
sns.histplot(data=dfFiltro,x='reading score', hue = 'race/ethnicity')

# %% [markdown]
# COMO LA PREPARACION INFLUYE EN LOS PUNTAJES

# %%
df=pd.read_csv("/content/drive/MyDrive/Ingeniería de Sistemas/2023-1/BigData/StudentsPerformance.csv")
df.head(5)  #Sirve para dibujar las primeros cinco filas de DF
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.catplot(x='test preparation course', y='math score', col='gender', kind='box', data =df)

# %%
sns.pairplot(data =df, hue = 'gender')
